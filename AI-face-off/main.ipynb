# %%
from datetime import datetime
from langchain_openai import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage, AIMessage
from dotenv import load_dotenv

load_dotenv()

llm = ChatOpenAI(model_name="gpt-4", temperature=0.7)

def timestamp():
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")

def run_ai_faceoff_battle(topic: str, rounds: int = 2):
    
    # Role instructions
    debater_a_prompt = f"You are Debater A. Argue in favor of the motion: '{topic}'."
    debater_b_prompt = f"You are Debater B. Argue against the motion: '{topic}'."
    judge_prompt = f"You are the Judge. After reviewing the full debate on '{topic}', decide who had stronger arguments and declare the winner."

    # Conversation history and logging
    messages = []
    transcript = []

    # Add topic announcement
    intro = f"The debate topic is: {topic}"
    messages.append(HumanMessage(content=intro))
    transcript.append({
        "speaker": "Moderator",
        "time": timestamp(),
        "message": intro
    })

    # Debate rounds
    for round_num in range(rounds):
        # Debater A
        messages.append(SystemMessage(content=debater_a_prompt))
        response_a = llm(messages)
        messages.append(AIMessage(content=response_a.content))
        transcript.append({
            "speaker": "Debater A",
            "time": timestamp(),
            "message": response_a.content
        })

        # Debater B
        messages.append(SystemMessage(content=debater_b_prompt))
        response_b = llm(messages)
        messages.append(AIMessage(content=response_b.content))
        transcript.append({
            "speaker": "Debater B",
            "time": timestamp(),
            "message": response_b.content
        })

    # Judge evaluation
    messages.append(SystemMessage(content=judge_prompt))
    response_judge = llm(messages)
    messages.append(AIMessage(content=response_judge.content))
    transcript.append({
        "speaker": "Judge",
        "time": timestamp(),
        "message": response_judge.content
    })

    return transcript

# %%
transcript = run_ai_faceoff_battle("money is better than education?", rounds=2)

for entry in transcript:
    print(f"[{entry['time']}] {entry['speaker']}: {entry['message']}\n")
# Out:
# C:\Users\nonsodev\AppData\Local\Temp\ipykernel_22076\2988217052.py:36: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response_a = llm(messages)
# [2025-05-17 16:54:56] Moderator: The debate topic is: money is better than education?
#
# [2025-05-17 16:55:11] Debater A: Ladies and Gentlemen,
#
# I am here to make a case for the motion, 'Money is better than education?'. This may seem controversial to some, but let me clarify my stance. I am not undermining the importance of education, but I am asserting that money plays a more critical role in our society today.
#
# Firstly, let's consider the purpose of education. The primary goal of education is to prepare individuals for a successful life. And how do we define success? In most societies, success is closely tied to wealth. Therefore, one can argue that the ultimate goal of education is to enable individuals to earn money.
#
# Secondly, in our current capitalist society, money is power. It provides access to resources, opportunities, healthcare, and even justice. Without money, even the most educated person would struggle to survive. Money enables us to provide for our families, invest in our futures, and make a positive impact in our communities.
#
# Education is undoubtedly important, but it’s not the only path to success. There are numerous examples of individuals who didn't receive formal education but still managed to amass wealth and succeed in life. Some of the world's most successful entrepreneurs, such as Bill Gates, Steve Jobs, and Mark Zuckerberg, are college dropouts.
#
# Moreover, education is becoming increasingly expensive. It's a bitter irony that many students are left with a mountain of debt, even after spending years pursuing higher education. In such a scenario, money can provide relief and open doors to opportunities that education alone may not.
#
# Furthermore, education does not guarantee employment. The job market is highly competitive, and a degree does not necessarily secure a well-paying job. In contrast, money offers financial independence and security.
#
# Lastly, money can also be used to gain knowledge and education. Whether it's through online courses, books, travel, or hiring tutors, money provides access to a wide range of learning opportunities outside the traditional education system.
#
# In conclusion, while education plays an essential role in personal development and societal progress, money offers tangible power and freedom in our current society. It provides immediate access to resources, opportunities, and security, making it, in many ways, superior to education. Therefore, I firmly believe that money is better than education.
#
# [2025-05-17 16:55:23] Debater B: Ladies and Gentlemen,
#
# Thank you for the opportunity to argue against the motion, 'Money is better than education?'. While it's undeniable that money plays an important role in our society, I firmly believe that the value of education is far superior.
#
# Firstly, education is not just about preparing us to earn money. It's about developing critical thinking skills, fostering creativity, and encouraging intellectual curiosity. Education shapes our character, instills moral values, and helps us understand the world around us. No amount of money can buy these invaluable attributes.
#
# Secondly, it is essential to understand that money is a finite resource, which can be lost or stolen. Education, on the other hand, is an everlasting asset. The knowledge acquired through education cannot be taken away.
#
# While money can certainly provide access to resources and opportunities, it is education that teaches us how to use these resources wisely. Without education, money can quickly be squandered or misused.
#
# Furthermore, it's important to note that while the examples of successful school or college dropouts are often highlighted, they are exceptions, not the rule. For every Bill Gates, there are millions of others who struggled due to a lack of education.
#
# Moreover, it's a flawed argument that education does not guarantee employment. In today's knowledge-based economy, education is more important than ever. The majority of well-paying jobs require some form of higher education. While it's true that education does not guarantee success, it certainly improves the odds.
#
# In terms of the rising cost of education, this is a valid concern. However, the solution isn't to devalue education but to work towards making it more accessible and affordable.
#
# Lastly, while money can buy educational resources, it cannot buy the discipline, motivation, and dedication required to learn. These are cultivated through a well-rounded education.
#
# In conclusion, while money provides temporary comfort and security, education offers long-term benefits, equipping individuals with the skills and knowledge to navigate life's challenges. It is education that lays the foundation for an enlightened, ethical, and progressive society. Therefore, I firmly believe that education is better than money.
#
# [2025-05-17 16:55:35] Debater A: Ladies and Gentlemen,
#
# I appreciate the points articulated by my opponent, but I maintain my stance: Money is better than education. Let's dissect this further.
#
# Education is undoubtedly important. However, it’s also true that formal education isn’t the only pathway to acquiring knowledge. With money, one has the liberty to choose how they wish to learn. This could be through travel, internships, workshops, or online courses. Money gives us the freedom to pursue knowledge on our terms, not just in the confines of a textbook or a classroom.
#
# While my opponent argues that education fosters critical thinking and creativity, I'd argue that it's not exclusive to formal education. Many successful entrepreneurs, artists, and innovators who didn't follow the traditional educational path have demonstrated exceptional critical thinking and creativity. They were able to do so because they had financial freedom and resources, which allowed them to think outside the box and take risks.
#
# Let's take a moment to consider the value of time. Money can buy time, which is our most precious resource. With financial stability, individuals can take time to pursue passions, spend time with loved ones or contribute to society in meaningful ways. No amount of education can buy this luxury.
#
# Yes, money is finite, but so is education. The relevance of what we learn today might not hold in the future. We live in a rapidly changing world where the nature of jobs and skills required are constantly evolving. However, money gives us the flexibility to adapt and learn new skills as per the demand of the time.
#
# Finally, money allows us to make a bigger impact in society. With money, we can fund charities, support causes we care about, and provide opportunities for others. This kind of contribution can often have a larger societal impact than education confined to one person.
#
# In conclusion, money is not just about buying materialistic things; it's about the freedom, flexibility, and opportunities it provides. It's not about undermining education but recognizing that money can, in many ways, play a more influential role in our society. Hence, I affirm that money is better than education.
#
# [2025-05-17 16:55:51] Debater B: Ladies and Gentlemen,
#
# While my esteemed opponent argues convincingly, I remain firm in my belief that education is superior to money.
#
# The argument that money allows for alternative forms of education is valid, but it's important to remember that not all knowledge is equal. Formal education provides a structured understanding of various disciplines, exposes us to diverse viewpoints, and develops a broad set of skills. This structured learning environment is irreplaceable and offers a fundamental base of knowledge that can be built upon throughout our lives.
#
# The claim that education doesn't foster creativity as effectively as financial freedom neglects the fact that many of the world's most innovative thinkers were shaped by their educational experiences. Albert Einstein, Marie Curie, Martin Luther King Jr., these individuals were all products of formal education. Their education laid the groundwork for their creativity and critical thinking.
#
# As for the argument that money can buy time, it's crucial to understand that time without purpose or direction can be meaningless. Education provides us with the intellectual tools to use our time effectively and purposefully.
#
# While money can indeed provide access to new skill learning, education equips us with the ability to learn. The foundational skills of reading, writing, and critical thinking taught in education are what allow us to adapt and learn new skills in the first place.
#
# Undeniably, money can enable us to contribute to society. However, education also empowers us to make significant societal contributions. Teachers, scientists, doctors, these professions require a high level of education and undoubtedly make a profound impact on society.
#
# Lastly, while it's true that money provides flexibility and opportunities, it's education that teaches us how to capitalize on these opportunities. Without education, we risk making uninformed decisions and misusing the opportunities money provides.
#
# In conclusion, money, while important, is a tool. Education, on the other hand, is the hand that wields the tool. It is education that empowers us, enriches us, and ultimately, equips us to earn and manage money effectively. Hence, I am resolute in my belief that education is better than money.
#
# [2025-05-17 16:55:57] Judge: After carefully considering both sides of the debate, I conclude that Debater B, arguing against the motion 'money is better than education?', delivered stronger arguments. Debater B effectively addressed the points raised by Debater A, providing compelling counter-arguments that emphasized the long-term benefits of education.
#
# While Debater A rightly pointed out the practical importance and flexibility that money offers, they failed to address Debater B's strong points about the foundational role education plays in developing critical thinking, moral values, and intellectual curiosity, which cannot be bought with money.
#
# Debater B also effectively argued that education provides the skills needed to earn and manage money effectively. By highlighting the lasting value and broad societal impacts of education, Debater B successfully demonstrated the superiority of education over money.
#
# Therefore, based on the strength and depth of the arguments presented, Debater B is declared the winner of this debate.
